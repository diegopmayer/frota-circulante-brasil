# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('Frota_Reg_UF-Tipo_Modelo_Fevereiro_2019.xls', usecols=[0, 4, 15, 16, 1])
df.columns = ['Regiões/Estado', 'Caminhões', 'Reboque', 'Semi-Reboque', 'Total de Veículos']

# %%
#para coletar sem filtro
#
df = pd.read_excel('Frota_Reg_UF-Tipo_Modelo_Fevereiro_2019.xls')

# %%
df[['Regiões/Estado', 'Caminhões', 'Reboque', 'Semi-Reboque', 'Total de Veículos']]
# Out:
#                                        Regiões/Estado  Caminhões    Reboque  \
# 0                                                 NaN        NaN        NaN
# 1            Grandes Regiões e\nUnidades da Federação      TOTAL   CAMINHÃO
# 2                                              Brasil  101346180    2773954
# 3                                               Norte    5303197     152525
# 4                                               Acre      280135       7219
# 5                                              Amapá      196646       4178
# 6                                            Amazonas     889093      20059
# 7                                               Pará     2029737      62314
# 8                                           Rondônia      992396      31148
# 9                                             Roraima     220600       5161
# 10                                          Tocantins     694590      22446
# ...

# %%
df.head(3)
# Out:
#   Frota de veículos, por tipo e com placa, segundo as Grandes Regiões e Unidades da Federação - FEV / 2019  \
# 0                                                NaN
# 1           Grandes Regiões e\nUnidades da Federação
# 2                                             Brasil
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4       Unnamed: 5   Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN              NaN          NaN
# 1      TOTAL  AUTOMÓVEL      BONDE   CAMINHÃO  CAMINHÃO TRATOR  CAMINHONETE
# 2  101346180   54995950         42    2773954           661225      7607773
#
#   Unnamed: 7         Unnamed: 8  Unnamed: 9  ... Unnamed: 13  Unnamed: 14  \
# 0        NaN                NaN         NaN  ...         NaN          NaN
# 1  CAMIONETA  CHASSI PLATAFORMA  CICLOMOTOR  ...      ÔNIBUS  QUADRICICLO
# 2    3445633               1762      392866  ...      630071          204
#
#   Unnamed: 15   Unnamed: 16 Unnamed: 17 Unnamed: 18     Unnamed: 19  \
# ...
